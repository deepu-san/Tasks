# %% [markdown]
# <a href="https://colab.research.google.com/github/deepu-san/Tasks/blob/main/World%20Population/World_Population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
path="https://raw.githubusercontent.com/deepu-san/Tasks/main/World%20Population/world_population.csv"
df = pd.read_csv(path)
df.head(3)
# Out:
#    Rank CCA3      Country  Capital Continent  2022 Population  \
# 0    36  AFG  Afghanistan    Kabul      Asia         41128771
# 1   138  ALB      Albania   Tirana    Europe          2842321
# 2    34  DZA      Algeria  Algiers    Africa         44903225
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796         12486631         10752971      652230
# 1          3295066          2941651          2324731       28748
# 2         25518074         18739378         13795915     2381741
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Country, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %% [markdown]
# No duplicate rows in Data frame. All Countries are Unique

# %%
plt.figure(figsize = (20,8))
plt.title("Top 20 Countries based on World Population Percentage")
sns.barplot(x='Country', y="World Population Percentage", data=df.nlargest(20,"World Population Percentage"))

# %%
df1=df.nlargest(20,"World Population Percentage")

fig = plt.figure(figsize =(10, 7))
plt.pie(df1["World Population Percentage"], labels = df1["Country"])
plt.title("Top 20 Countries based on World Population Percentage")
# Out:
# Text(0.5, 1.0, 'Top 20 Countries based on World Population Percentage')

# %%
plt.figure(figsize = (18,8))
plt.title("Top 20 Countries based on Growth Rate")
sns.barplot(x='Country', y="Growth Rate", data=df.nlargest(20,"Growth Rate"))

# %%
plt.figure(figsize = (20,8))
plt.title("Top 20 Countries based on Density")
sns.barplot(x='Country', y="Density (per km²)", data=df.nlargest(20,"Density (per km²)"))

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df1=df.nlargest(10,"World Population Percentage")
ax=df1.plot(x="Country", y=['1970 Population','1980 Population','1990 Population','2000 Population',"2010 Population", "2015 Population","2020 Population","2022 Population"],
            kind="bar",title='Change in Population of Top 10 Countries (by population percentage) from 1970 to 2022',fontsize=12, figsize=(13, 8))
#ax.title("Change in Population of Top 10 Countries (by population percentage) from 1970 to 2022")
